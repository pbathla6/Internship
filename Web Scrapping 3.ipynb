# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\hp\anaconda3\lib\site-packages (4.10.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (1.26.16)
# Requirement already satisfied: trio~=0.17 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (0.10.3)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (2023.5.7)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: exceptiongroup in c:\users\hp\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.1.2)
# Requirement already satisfied: wsproto>=0.14 in c:\users\hp\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\hp\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\hp\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import requests
import regex as re

# %%
driver = webdriver.Chrome()

# %% [markdown]
# # Question 1

# %%
user = input("Enter your item: ")
# Out:
# Enter your item: Guitar

# %% [markdown]
# # Question 2

# %%
driver.get("https://www.amazon.in")

# %%
role1=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
role1.send_keys('Guitar')

role2=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
role2.click()

# %%
page_url=[]
start = 0
end = 3
for page in range(start,end):
    
    url=driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in url:
        page_url.append(i.get_attribute('href'))
next_button=driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
next_button.click()

# %%
len(page_url)
# Out:
# 210

# %%
Brand=[]
Title=[]
Price=[]
Replacement=[]
Stock=[]
Delivery=[]

# %%
for i in page_url:
    driver.get(i)
    
    try:
        title=driver.find_element(By.XPATH,'//span[@class="a-size-large product-title-word-break"]')
        Title.append(title.text)
    except NoSuchElementException:
        Title.append('-')
        
    try:
        brand=driver.find_element(By.XPATH,'//*[@id="productOverview_feature_div"]/div/table/tbody/tr[1]/td[2]/span')
        Brand.append(brand.text)
    except NoSuchElementException:
        Brand.append('-')
        
        
    try:
        price=driver.find_element(By.XPATH,'//div[@id="corePrice_feature_div"]')
        Price.append(price.text.split('\n')[0])
    except NoSuchElementException:
        Price.append('-')
        
        
    try:
        replace=driver.find_element(By.XPATH,'//*[@id="iconfarmv2_feature_div"]/div[2]/div[1]/div[1]/div[1]/div[2]/div[1]/ol/li[3]/div[1]/span/div[2]/span')
        Replacement.append(replace.text)
    except NoSuchElementException:
        Replacement.append('-')
        
        
        
    try:
        stock=driver.find_element(By.XPATH,'//div[@class="a-section a-spacing-none a-spacing-top-micro }"]')
        Stock.append(stock.text)
    except NoSuchElementException:
        Stock.append('-')
        
        
    try:
        delivery=driver.find_element(By.XPATH,'//*[@id="deliveryBlockContainer"]/div[1]/div[1]/div[1]/div[1]/span/span[1]')
        Delivery.append(delivery.text)
    except NoSuchElementException:
        Delivery.append('-')

# %%
print(len(Brand),len(Delivery),len(Stock),len(Price),len(Title),len(Replacement))
# Out:
# 210 210 210 210 210 210

# %%
df=pd.DataFrame({"Brand Name":Brand,"Name of the Product":Title,"Price":Price,"Return/Exchange":Replacement,"Expected Delivery":Delivery,"Availability":Stock,"Product URL":page_url})
df
# Out:
#     Brand Name                                Name of the Product       Price  \
# 0      Kadence  Kadence rosewood Guitar Frontier Series, Elect...  ₹4,999\n00
# 1        VAULT  Vault DA20 Dreadnought Acoustic Guitar With Gi...  ₹4,899\n00
# 2      Kadence  Kadence Frontier guitar with Online Guitar lea...  ₹4,399\n00
# 3       Henrix  Henrix 38C 38 Inch Cutaway Acoustic Guitar Wit...  ₹2,999\n00
# 4       JUAREZ  Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...  ₹1,999\n00
# ..         ...                                                ...         ...
# 205      Metal  TechnoBuyers Professional Metal Guitar Foot Re...    ₹449\n00
# 206     JUAREZ  Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...  ₹1,999\n00
# 207     Intern  Intern INT-38C Right hand Acoustic Guitar Kit,...  ₹2,099\n00
# 208     YAMAHA  Yamaha F280 Acoustic Rosewood Guitar (Natural,...  ₹7,099\n00
# 209     JUAREZ  Juarez Lindenwood Acoustic Guitar Kit, 38 Inch...  ₹1,999\n00
#
#         Return/Exchange    Expected Delivery Availability  \
# 0    7 days Replacement    Monday, 14 August     In stock
# 1    7 days Replacement  Saturday, 12 August     In stock
# 2    7 days Replacement    Monday, 14 August     In stock
# 3    7 days Replacement  Saturday, 12 August     In stock
# 4    7 days Replacement    Monday, 14 August     In stock
# ..                  ...                  ...          ...
# 205  7 days Replacement   Tuesday, 15 August     In stock
# 206  7 days Replacement   Tuesday, 15 August     In stock
# 207  7 days Replacement   Tuesday, 15 August     In stock
# 208  7 days Replacement   Tuesday, 15 August     In stock
# 209  7 days Replacement   Tuesday, 15 August     In stock
#
#                                            Product URL
# 0    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 1    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 3    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 4    https://www.amazon.in/Juarez-Acoustic-Cutaway-...
# ..                                                 ...
# 205  https://www.amazon.in/Technobuyers-Professiona...
# 206  https://www.amazon.in/Juarez-Acoustic-Cutaway-...
# 207  https://www.amazon.in/Intern-INT-38C-Acoustic-...
# 208  https://www.amazon.in/Yamaha-F280-Acoustic-Gui...
# 209  https://www.amazon.in/JUAREZ-JRZ38C-Acoustic-S...
#
# [210 rows x 7 columns]

# %%
df.to_csv('question2.csv')

# %% [markdown]
# # Question 3

# %%
driver.get("https://images.google.com")

# %%
role21= driver.find_element(By.XPATH,'//textarea[@class="gLFyf"]')
role21.send_keys('fruits')

role22=driver.find_element(By.XPATH,'//div[@class="zgAlFc"]')
role22.click()

# %%
image_urls=[]

for _ in range(20):
    driver.execute_script("window.scrollBy(0,100)")
images=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

for image in images:
    source=image.get_attribute('src')
    if source is not None:
        if (source[0:4] == 'http'):
            image_urls.append(source)
            
            
for i in range(len(image_urls)):
    if i>10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response=requests.get(image_urls[i])
    file = open(r"C:\Users\hp\OneDrive\Desktop\down"+str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images
# Downloading 10 of 10 images

# %%
driver.get("https://images.google.com")

# %%
role23= driver.find_element(By.XPATH,'//textarea[@class="gLFyf"]')
role23.send_keys('cars')

role24=driver.find_element(By.XPATH,'//div[@class="zgAlFc"]')
role24.click()

# %%
cars_urls=[]

for _ in range(20):
    driver.execute_script("window.scrollBy(0,100)")
car=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

for i in car:
    source=i.get_attribute('src')
    if source is not None:
        if (source[0:4] == 'http'):
            cars_urls.append(source)
            
            
for i in range(len(cars_urls)):
    if i>10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response=requests.get(cars_urls[i])
    file = open(r"C:\Users\hp\OneDrive\Desktop\down"+str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images
# Downloading 10 of 10 images

# %%
driver.get("https://images.google.com")

# %%
role25= driver.find_element(By.XPATH,'//textarea[@class="gLFyf"]')
role25.send_keys('machine learning')

role26=driver.find_element(By.XPATH,'//div[@class="zgAlFc"]')
role26.click()

# %%
machine_learning=[]

for _ in range(20):
    driver.execute_script("window.scrollBy(0,100)")
machine=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

for i in machine:
    source=i.get_attribute('src')
    if source is not None:
        if (source[0:4] == 'http'):
            machine_learning.append(source)
            
            
for i in range(len(machine_learning)):
    if i>10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response=requests.get(machine_learning[i])
    file = open(r"C:\Users\hp\OneDrive\Desktop\down"+str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images
# Downloading 10 of 10 images

# %%
driver.get("https://images.google.com")

# %%
role27= driver.find_element(By.XPATH,'//textarea[@class="gLFyf"]')
role27.send_keys('guitar')

role28=driver.find_element(By.XPATH,'//div[@class="zgAlFc"]')
role28.click()

# %%
guitar=[]

for _ in range(20):
    driver.execute_script("window.scrollBy(0,100)")
g=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

for i in g:
    source=i.get_attribute('src')
    if source is not None:
        if (source[0:4] == 'http'):
            guitar.append(source)
            
            
for i in range(len(guitar)):
    if i>10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response=requests.get(guitar[i])
    file = open(r"C:\Users\hp\OneDrive\Desktop\down"+str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images
# Downloading 10 of 10 images

# %%
driver.get("https://images.google.com")

# %%
role29= driver.find_element(By.XPATH,'//textarea[@class="gLFyf"]')
role29.send_keys('cakes')

role30=driver.find_element(By.XPATH,'//div[@class="zgAlFc"]')
role30.click()

# %%
cakes=[]

for _ in range(20):
    driver.execute_script("window.scrollBy(0,100)")
g=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

for i in g:
    source=i.get_attribute('src')
    if source is not None:
        if (source[0:4] == 'http'):
            guitar.append(source)
            
            
for i in range(len(guitar)):
    if i>10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response=requests.get(guitar[i])
    file = open(r"C:\Users\hp\OneDrive\Desktop\down"+str(i)+".jpg","wb")
    file.write(response.content)

# %% [markdown]
# # Question 4

# %%
driver.get("https://www.flipkart.com")

# %%
role3=driver.find_element(By.XPATH,'//input[@class="Pke_EE"]')
role3.send_keys('Oneplus Nord')

role4=driver.find_element(By.XPATH,'//button[@class="_2iLD__"]')
role4.click()

# %%
Company=[]
Smartphone_Name=[]
Colour=[]
RAM=[]
Storage=[]
Primary_Camera=[]
Secondary_Camera=[]
Display_Size=[]
Battery_Capacity=[]
Price=[]
Product_URL=[]

# %%
role5=driver.find_elements(By.CLASS_NAME,'_1fQZEK')
for i in role5:
    Product_URL.append(i.get_attribute('href'))

# %%
len(Product_URL)
# Out:
# 24

# %%
for i in Product_URL:
    driver.get(i)
    
    
    try:
        company=driver.find_element(By.XPATH,'//span[@class="B_NuCI"]')
        Company.append(company.text.split('Nord')[0])
    except NoSuchElementException:
        Company.append('-')
        
    
    try:
        smartphone=driver.find_element(By.XPATH,'//span[@class="B_NuCI"]')
        Smartphone_Name.append(smartphone.text.split('(')[0])
    except NoSuchElementException:
        Smartphone_Name.append('-')
        
        
    try:
        colour=driver.find_element(By.XPATH,'//*[@class="_14cfVK"]/tbody/tr[4]/td[2]/ul/li')
        Colour.append(colour.text)
    except NoSuchElementException:
        Colour.append('-')
        
    
    try:
        ram=driver.find_element(By.XPATH,'//*[@class="_2418kt"]/ul/li[1]')
        RAM.append(ram.text.split('|')[0])
    except NoSuchElementException:
        RAM.append('-')
        
        
    try:
        storage=driver.find_element(By.XPATH,'//*[@class="_2418kt"]/ul/li[1]')
        Storage.append(storage.text.split('|')[1])
    except NoSuchElementException:
        Storage.append('-')
        
    try:
        primary=driver.find_element(By.XPATH,'//*[@class="_2418kt"]/ul/li[3]')
        Primary_Camera.append(primary.text.split('|')[0])
    except NoSuchElementException:
        Primary_Camera.append('-')
        
        
    try:
        secondary=driver.find_element(By.XPATH,'//*[@class="_2418kt"]/ul/li[3]')
        Secondary_Camera.append(secondary.text)
    except NoSuchElementException:
        Secondary_Camera.append('-')
    
        
    try:
        display=driver.find_element(By.XPATH,'//*[@class="_2418kt"]/ul/li[2]')
        Display_Size.append(display.text.split('(')[0])
    except NoSuchElementException:
        Display_Size.append('-')
        
        
    try:
        battery=driver.find_element(By.XPATH,'//*[@class="_2418kt"]/ul/li[4]')
        Battery_Capacity.append(battery.text.split('B')[0])
    except NoSuchElementException:
        Battery_Capacity.append('-')
        
        
    try:
        price=driver.find_element(By.XPATH,'//div[@class="_30jeq3 _16Jk6d"]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('-')

# %%
print(len(Price),len(Battery_Capacity),len(Display_Size),len(Secondary_Camera),len(Primary_Camera),len(Storage),len(RAM),len(Colour),len(Smartphone_Name),len(Company))
# Out:
# 24 24 24 24 24 24 24 24 24 24

# %%
df1=pd.DataFrame({"Brand":Company,"Smartphone Name":Smartphone_Name,"Colour":Colour,"RAM":RAM,"Storage":Storage,"Primary Camera":Primary_Camera,"Secondary Camera":Secondary_Camera,"Display Size":Display_Size,"Battery Capacity":Battery_Capacity,"Price":Price,"Product URL":Product_URL})
df1
# Out:
#                                                 Brand  \
# 0                                            OnePlus
# 1                                            OnePlus
# 2                                            OnePlus
# 3                                            OnePlus
# 4                                            OnePlus
# 5                                            OnePlus
# 6                                            OnePlus
# 7   OnePlus NORD CE2 LITE 5G (Blue Tide, 128 GB)  ...
# 8                                            OnePlus
# 9                                            OnePlus
# 10                                           OnePlus
# 11                                           OnePlus
# 12                                           OnePlus
# 13                                           OnePlus
# 14                                           OnePlus
# 15                                           OnePlus
# 16                                           OnePlus
# 17                                           OnePlus
# 18                                           OnePlus
# 19                                           OnePlus
# 20  OnePlus NORD CE2 LITE 5G (Blue, Black, 128 GB)...
# 21                                           OnePlus
# 22                                           OnePlus
# 23                                           OnePlus
#
#                Smartphone Name          Colour         RAM      Storage  \
# 0   OnePlus Nord CE 2 Lite 5G        Blue Tide   6 GB RAM    128 GB ROM
# 1   OnePlus Nord CE 2 Lite 5G       Black Dusk   6 GB RAM    128 GB ROM
# 2           OnePlus Nord 3 5G      Misty Green   8 GB RAM    128 GB ROM
# 3           OnePlus Nord 3 5G      Misty Green  16 GB RAM    256 GB ROM
# 4          OnePlus Nord 2T 5G      Gray Shadow   8 GB RAM    128 GB ROM
# 5           OnePlus Nord 3 5G     Tempest Gray  16 GB RAM    256 GB ROM
# 6           OnePlus Nord 3 5G     Tempest Gray   8 GB RAM    128 GB ROM
# 7    OnePlus NORD CE2 LITE 5G        Blue Tide   6 GB RAM    128 GB ROM
# 8   OnePlus Nord CE 3 Lite 5G   Chromatic Gray   8 GB RAM    128 GB ROM
# 9                OnePlus Nord        Gray Onyx   8 GB RAM    128 GB ROM
# 10          OnePlus Nord 2 5G      Gray Sierra   8 GB RAM    128 GB ROM
# 11          OnePlus Nord 2 5G        Blue Haze  12 GB RAM    256 GB ROM
# 12         OnePlus Nord CE 5G        Blue Void  12 GB RAM    256 GB ROM
# 13          OnePlus Nord 2 5G          PAC-MAN  12 GB RAM    256 GB ROM
# 14         OnePlus Nord 2T 5G      Gray Shadow   8 GB RAM    128 GB ROM
# 15         OnePlus Nord 2T 5G         Jade Fog   8 GB RAM    128 GB ROM
# 16         OnePlus Nord 2T 5G      Gray Shadow   8 GB RAM    128 GB ROM
# 17               OnePlus Nord        Gray Onyx   6 GB RAM     64 GB ROM
# 18         OnePlus Nord 2T 5G      Gray Shadow   8 GB RAM    128 GB ROM
# 19  OnePlus Nord CE 3 Lite 5G      Pastel Lime   8 GB RAM    128 GB ROM
# 20   OnePlus NORD CE2 LITE 5G      Blue, Black   6 GB RAM    128 GB ROM
# 21  OnePlus Nord CE 3 Lite 5G   Chromatic Gray   8 GB RAM    256 GB ROM
# 22  OnePlus Nord CE 3 Lite 5G      Pastel Lime   8 GB RAM    256 GB ROM
# 23         OnePlus Nord 2T 5G         Jade Fog   8 GB RAM    128 GB ROM
#
#        Primary Camera                           Secondary Camera Display Size  \
# 0   64MP Rear Camera        64MP Rear Camera | 16MP Front Camera    16.74 cm
# 1   64MP Rear Camera        64MP Rear Camera | 16MP Front Camera    16.74 cm
# 2    50MP Rear Camera                           50MP Rear Camera    17.12 cm
# 3    50MP Rear Camera                           50MP Rear Camera    17.12 cm
# 4   50MP Rear Camera        50MP Rear Camera | 32MP Front Camera    17.02 cm
# 5    50MP Rear Camera                           50MP Rear Camera    17.12 cm
# 6    50MP Rear Camera                           50MP Rear Camera    17.12 cm
# 7    64MP Rear Camera                           64MP Rear Camera    16.74 cm
# 8   108MP Rear Camera                          108MP Rear Camera    17.07 cm
# 9         48MP + 8MP   48MP + 8MP | 32MP + 8MP Dual Front Camera    16.36 cm
# 10   50MP Rear Camera                           50MP Rear Camera    16.33 cm
# 11   50MP Rear Camera                           50MP Rear Camera    16.33 cm
# 12   64MP Rear Camera                           64MP Rear Camera    16.33 cm
# 13   50MP Rear Camera                           50MP Rear Camera    16.33 cm
# 14   50MP Rear Camera                           50MP Rear Camera    17.02 cm
# 15  50MP Rear Camera        50MP Rear Camera | 32MP Front Camera    17.02 cm
# 16   50MP Rear Camera                           50MP Rear Camera    17.02 cm
# 17        48MP + 8MP   48MP + 8MP | 32MP + 8MP Dual Front Camera    16.36 cm
# 18   50MP Rear Camera                           50MP Rear Camera    17.02 cm
# 19  108MP Rear Camera                          108MP Rear Camera    17.07 cm
# 20   64MP Rear Camera                           64MP Rear Camera    16.74 cm
# 21  108MP Rear Camera                          108MP Rear Camera    17.07 cm
# 22  108MP Rear Camera                          108MP Rear Camera    17.07 cm
# 23   50MP Rear Camera                           50MP Rear Camera    17.02 cm
#
#    Battery Capacity    Price  \
# 0         5000 mAh   ₹17,797
# 1         5000 mAh   ₹17,722
# 2         5000 mAh   ₹32,796
# 3         5000 mAh   ₹37,494
# 4         4500 mAh   ₹28,999
# 5         5000 mAh   ₹37,265
# 6         5000 mAh   ₹32,840
# 7         5000 mAh   ₹17,998
# 8         5000 mAh   ₹19,999
# 9         4115 mAh   ₹24,990
# 10        4500 mAh   ₹29,999
# 11        4500 mAh   ₹34,990
# 12        4500 mAh   ₹27,999
# 13        4500 mAh   ₹37,999
# 14        4500 mAh   ₹28,899
# 15        4500 mAh   ₹26,578
# 16        4500 mAh   ₹28,988
# 17        4115 mAh   ₹22,689
# 18        4500 mAh   ₹27,599
# 19        5000 mAh   ₹18,999
# 20        5000 mAh   ₹17,999
# 21        5000 mAh   ₹21,990
# 22        5000 mAh   ₹21,499
# 23        4500 mAh   ₹27,899
#
#                                           Product URL
# 0   https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 1   https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 2   https://www.flipkart.com/oneplus-nord-3-5g-mis...
# 3   https://www.flipkart.com/oneplus-nord-3-5g-mis...
# 4   https://www.flipkart.com/oneplus-nord-2t-5g-gr...
# 5   https://www.flipkart.com/oneplus-nord-3-5g-tem...
# 6   https://www.flipkart.com/oneplus-nord-3-5g-tem...
# 7   https://www.flipkart.com/oneplus-nord-ce2-lite...
# 8   https://www.flipkart.com/oneplus-nord-ce-3-lit...
# 9   https://www.flipkart.com/oneplus-nord-gray-ony...
# 10  https://www.flipkart.com/oneplus-nord-2-5g-gra...
# 11  https://www.flipkart.com/oneplus-nord-2-5g-blu...
# 12  https://www.flipkart.com/oneplus-nord-ce-5g-bl...
# 13  https://www.flipkart.com/oneplus-nord-2-5g-pac...
# 14  https://www.flipkart.com/oneplus-nord-2t-5g-gr...
# 15  https://www.flipkart.com/oneplus-nord-2t-5g-ja...
# 16  https://www.flipkart.com/oneplus-nord-2t-5g-gr...
# 17  https://www.flipkart.com/oneplus-nord-gray-ony...
# 18  https://www.flipkart.com/oneplus-nord-2t-5g-gr...
# 19  https://www.flipkart.com/oneplus-nord-ce-3-lit...
# 20  https://www.flipkart.com/oneplus-nord-ce2-lite...
# 21  https://www.flipkart.com/oneplus-nord-ce-3-lit...
# 22  https://www.flipkart.com/oneplus-nord-ce-3-lit...
# 23  https://www.flipkart.com/oneplus-nord-2t-5g-ja...

# %% [markdown]
# # Question 5

# %%
driver.get("https://www.google.com/maps")

# %%
role16=driver.find_element(By.XPATH,'//input[@class="searchboxinput xiQnY"]')
role16.send_keys('Delhi')

role17=driver.find_element(By.XPATH,'//div[@class="pzfvzf"]')
role17.click()
time.sleep(5)

# %%
Latitude=[]
Longitude=[]

# %%
try:
    
    url_string = driver.current_url
    print("URL EXTRACTED: ", url_string)
    lat_lng = re.findall(r'@(.*)data',url_string)
    new=lat_lng[0].split(',')
    Longitude=new[1]
    Latitude=new[0]
    
except NoSuchElementException:
    url_string.append('-')
# Out:
# URL EXTRACTED:  https://www.google.com/maps/place/Delhi/@28.6436846,76.7635598,10z/data=!3m1!4b1!4m6!3m5!1s0x390cfd5b347eb62d:0x37205b715389640!8m2!3d28.7040592!4d77.1024902!16zL20vMDlmMDc?entry=ttu

# %%
Latitude
# Out:
# '28.6436846'

# %%
Longitude
# Out:
# '76.7635598'

# %% [markdown]
# # Question 6

# %%
driver.get("https://www.digit.in")

# %%
role6=driver.find_element(By.XPATH,'//span[@class="arrow_down laptops"]')
role6.click()

role7=driver.find_element(By.XPATH,'/html/body/div[2]/div/ul/li[2]/div[2]/div/div[1]/span[4]/strong')
role7.click()

role8=driver.find_element(By.XPATH,'/html/body/div[2]/div/ul/li[2]/div[2]/div/div[5]/div/div[2]/a/div')
role8.click()

time.sleep(5)

# %%
Lapi_URL=[]
Lapi_name=[]
Weight=[]
OS=[]
Price_Lapi=[]
Processor=[]
Display=[]
Memory=[]

# %%
role9=driver.find_elements(By.XPATH,'//span[@class="datahreflink"]')
for i in role9[0:7]:
    Lapi_URL.append(i.get_attribute('data-href'))
    
time.sleep(5)

# %%
for i in Lapi_URL:
    driver.get(i)
    
    
    try:
        lapi=driver.find_element(By.XPATH,'//div[@class="heading-wraper"]')
        Lapi_name.append(lapi.text.split('\n')[0])
    except NoSuchElementException:
        Lapi_name.append('-')
        
        
    try:
        display=driver.find_element(By.XPATH,'//*[@class="key_specifications  notspecs "]/div[1]/ul/li[2]/div/p[2]/strong')
        Display.append(display.text)
    except NoSuchElementException:
        Display.append('-')
        
        
    try:
        os=driver.find_element(By.XPATH,'//*[@class="key_specifications  notspecs "]/div[1]/ul/li/div/p[2]/strong')
        OS.append(os.text)
    except NoSuchElementException:
        OS.append('-')
        
        
        
    try:
        processor=driver.find_element(By.XPATH,'//*[@class="key_specifications  notspecs "]/div[1]/ul/li[3]/div/p[2]/strong')
        Processor.append(processor.text)
    except NoSuchElementException:
        Processor.append('-')
        
    try:
        memory=driver.find_element(By.XPATH,'//*[@class="key_specifications  notspecs "]/div[1]/ul/li[4]/div/p[2]/strong')
        Memory.append(memory.text)
    except NoSuchElementException:
        Memory.append('-')
        
        
        
    try:
        price=driver.find_element(By.XPATH,'//*[@class="price_sec"]/div/h2/strong')
        Price_Lapi.append(price.text)
    except NoSuchElementException:
        Price_Lapi.append('-')
        
        
        
    try:
        weight=driver.find_element(By.XPATH,'//*[@class="speci_details"]/div[1]/div[5]/table/tbody/tr[1]/td[3]')
        Weight.append(weight.text)
    except NoSuchElementException:
        Weight.append('-')

# %%
print(len(Lapi_URL),len(Weight),len(OS),len(Memory),len(Display),len(Price_Lapi),len(Processor),len(Lapi_name))
# Out:
# 7 7 7 7 7 7 7 7

# %%
df2=pd.DataFrame({"Name":Lapi_name,"OS":OS,"Processor":Processor,"Display":Display,"Memory":Memory,"Weight In Kg":Weight,"Price":Price_Lapi,"Product URL":Lapi_URL})
df2
# Out:
#                                                 Name               OS  \
# 0       HP Omen 17-ck2008TX 13th Gen Core i7-13700HX  Windows 11 Home
# 1  MSI GT77 Titan 12UHS-054IN 12th Gen Core i9-12...  Windows 11 Home
# 2  Lenovo Legion 5i Pro 12th Gen Core i7-12700H (...  Windows 11 Home
# 3  ASUS ROG Strix Scar 18 G834JZ-N5041WS 13th Gen...  Windows 11 Home
# 4  Acer Predator Helios Neo 16 13th Gen Core i7-1...  Windows 11 Home
# 5  ASUS ROG Zephyrus G14 Ryzen 9-6900HS (GA402RJZ...  Windows 11 Home
# 6  MSI Cyborg 15 12th Gen Core i7-12650H (A12VF-2...  Windows 11 Home
#
#                                   Processor              Display  \
# 0  13th Gen Intel Core i7-13700HX | 5.0 GHz  17.3" (2560 x 1440)
# 1  12th Gen Intel Core i9-12900HX | 3.6 GHz  17.3" (3840 x 2160)
# 2   12th Gen Intel Core i7-12700H | 4.7 GHz    16" (2560 x 1600)
# 3  13th Gen Intel Core i9-13980HX | 2.2 GHz    18" (1920 x 1200)
# 4       13th Gen Intel Core i7-13700HX | NA    16" (2560 x 1600)
# 5              AMD Ryzen 9-6900HS | 4.9 GHz    14" (1920 x 1200)
# 6   12th Gen Intel Core i7-12650H | 4.7 GHz  15.6" (1920 x 1080)
#
#                 Memory Weight In Kg      Price  \
# 0  1 TB SSD/16 GB DDR5         2.78  ₹ 269,777
# 1  2 TB SSD/64 GB DDR5          3.3  ₹ 499,990
# 2  1 TB SSD/32 GB DDR5          3.6  ₹ 218,000
# 3  1 TB SSD/32 GB DDR5          3.1  ₹ 279,990
# 4  1 TB SSD/16 GB DDR5          2.6  ₹ 149,990
# 5  1 TB SSD/16 GB DDR5         1.65  ₹ 156,990
# 6  1 TB SSD/16 GB DDR5         1.98  ₹ 130,990
#
#                                          Product URL
# 0  https://www.digit.in/laptops/hp-omen-17-ck2008...
# 1  https://www.digit.in/laptops/msi-gt77-titan-12...
# 2  https://www.digit.in/laptops/lenovo-legion-5i-...
# 3  https://www.digit.in/laptops/asus-rog-strix-sc...
# 4  https://www.digit.in/laptops/acer-predator-hel...
# 5  https://www.digit.in/laptops/asus-rog-zephyrus...
# 6  https://www.digit.in/laptops/msi-cyborg-15-12t...

# %% [markdown]
# # Question 7

# %%
driver.get("https://www.forbes.com")

# %%
role10=driver.find_element(By.XPATH,'//div[@class="_69hVhdY4"]')
role10.click()

time.sleep(2)

# %%
role11=driver.find_element(By.XPATH,'//*[@class="mpBfVZz3"]/span[1]')
role11.click()

time.sleep(2)

# %%
role12=driver.find_element(By.XPATH,'//*[@class="nZ7gK18V KvNFBOfs"]/div[3]/ul/li/a')
role12.click()

time.sleep(2)

# %%
Bill_Name=[]
Net_worth=[]
Age=[]
Country=[]
Source=[]
Industry=[]
Rank=[]

# %%
billname=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[3]/div[2]/div[2]/div[2]/div[1]/div[1]/div[1]/div[2]/div[1]/div[1]')
Bill_Name.append(billname.text.split('\n')[1])

billage=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[3]/div[2]/div[2]/div[2]/div[1]/div[1]/div[1]/div[2]/div[1]/div[1]')
Age.append(billage.text.split('\n')[3])

billworth=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[3]/div[2]/div[2]/div[2]/div[1]/div[1]/div[1]/div[2]/div[1]/div[1]')
Net_worth.append(billworth.text.split('\n')[2])

billcountry=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[3]/div[2]/div[2]/div[2]/div[1]/div[1]/div[1]/div[2]/div[1]/div[1]')
Country.append(billcountry.text.split('\n')[4])

billsource=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[3]/div[2]/div[2]/div[2]/div[1]/div[1]/div[1]/div[2]/div[1]/div[1]')
Source.append(billsource.text.split('\n')[5])

billindustry=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[3]/div[2]/div[2]/div[2]/div[1]/div[1]/div[1]/div[2]/div[1]/div[1]')
Industry.append(billindustry.text.split('\n')[6])

billrank=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[3]/div[2]/div[2]/div[2]/div[1]/div[1]/div[1]/div[2]/div[1]/div[1]')
Rank.append(billrank.text.split('\n')[0])

# %%
df4=pd.DataFrame({"Rank":Rank,"Billionare Name":Bill_Name,"Net_worth":Net_worth,"Age":Age,"Country":Country,"Source":Source,"Industry":Industry})
df4
# Out:
#   Rank           Billionare Name Net_worth Age Country Source  \
# 0    1  Bernard Arnault & family    $211 B  74  France   LVMH
#
#            Industry
# 0  Fashion & Retail

# %%
driver.get("https://www.forbes.com")

# %%
role13=driver.find_element(By.XPATH,'//div[@class="_69hVhdY4"]')
role13.click()

time.sleep(2)

# %%
role14=driver.find_element(By.XPATH,'/html/body/div[1]/header/nav/div[1]/div[1]/div/div[2]/ul/li[2]/div[1]')
role14.click()

time.sleep(2)

# %%
role15=driver.find_element(By.XPATH,'/html/body/div[1]/header/nav/div[1]/div[1]/div/div[2]/ul/li[2]/div[2]/div[3]/ul/li[1]/a')
role15.click()

time.sleep(2)

# %%
Bill_Name=[]
Net_worth=[]
Age=[]
Country=[]
Source=[]
Rank=[]
Industry=[]

# %%
try:
    rank=driver.find_elements(By.XPATH,'//div[@class="TableRow_row__L-0Km"]')
    for i in rank[0:199]:
        Rank.append(i.text.split('\n')[0])
        
except NoSuchElementException:
    Rank.append('-')


try:
    bill=driver.find_elements(By.XPATH,'//div[@class="TableRow_row__L-0Km"]')
    for i in bill[0:199]:
        Bill_Name.append(i.text.split('\n')[1])
        
except NoSuchElementException:
    Bill_Name.append('-')
    
    
try:    
    worth=driver.find_elements(By.XPATH,'//div[@class="TableRow_row__L-0Km"]')
    for i in worth[0:199]:
        Net_worth.append(i.text.split('\n')[2])
        
except NoSuchElementException:
    Net_worth.append('-')
    

try:
    age=driver.find_elements(By.XPATH,'//div[@class="TableRow_row__L-0Km"]')
    for i in age[0:199]:
        Age.append(i.text.split('\n')[3])
        
except NoSuchElementException:
    Age.append('-')
    
    

try:    
    country=driver.find_elements(By.XPATH,'//div[@class="TableRow_row__L-0Km"]')
    for i in country[0:199]:
        Country.append(i.text.split('\n')[4])
        
except NoSuchElementException:
    Country.append('-')
    
    
try:
    source=driver.find_elements(By.XPATH,'//div[@class="TableRow_row__L-0Km"]')
    for i in source[0:199]:
        Source.append(i.text.split('\n')[5])
        
except NoSuchElementException:
    Source.append('-')
    
    
        
try:
    industry=driver.find_elements(By.XPATH,'//div[@class="TableRow_row__L-0Km"]')
    for i in industry[0:199]:
        Industry.append(i.text.split('\n')[6])
            
except NoSuchElementException:
    Industry.append('-')

# %%
df3=pd.DataFrame({"Rank":Rank,"Billionare Name":Bill_Name,"Net_worth":Net_worth,"Age":Age,"Country":Country,"Source":Source,"Industry":Industry})
df3
# Out:
#     Rank     Billionare Name Net_worth Age        Country              Source  \
# 0      2           Elon Musk    $180 B  51  United States       Tesla, SpaceX
# 1      3          Jeff Bezos    $114 B  59  United States              Amazon
# 2      4       Larry Ellison    $107 B  78  United States              Oracle
# 3      5      Warren Buffett    $106 B  92  United States  Berkshire Hathaway
# 4      6          Bill Gates    $104 B  67  United States           Microsoft
# ..   ...                 ...       ...  ..            ...                 ...
# 194  195         Jin Baofang    $9.6 B  70          China        Solar panels
# 195  195  Luo Liguo & family    $9.6 B  67          China           Chemicals
# 196  195        Marijke Mars    $9.6 B  58  United States     Candy, pet food
# 197  195         Pamela Mars    $9.6 B  62  United States     Candy, pet food
# 198  195        Valerie Mars    $9.6 B  64  United States     Candy, pet food
#
#                   Industry
# 0               Automotive
# 1               Technology
# 2               Technology
# 3    Finance & Investments
# 4               Technology
# ..                     ...
# 194                 Energy
# 195          Manufacturing
# 196        Food & Beverage
# 197        Food & Beverage
# 198        Food & Beverage
#
# [199 rows x 7 columns]

# %%
df5=pd.concat([df4,df3],ignore_index=True)

df5
# Out:
#     Rank           Billionare Name Net_worth Age        Country  \
# 0      1  Bernard Arnault & family    $211 B  74         France
# 1      2                 Elon Musk    $180 B  51  United States
# 2      3                Jeff Bezos    $114 B  59  United States
# 3      4             Larry Ellison    $107 B  78  United States
# 4      5            Warren Buffett    $106 B  92  United States
# ..   ...                       ...       ...  ..            ...
# 195  195               Jin Baofang    $9.6 B  70          China
# 196  195        Luo Liguo & family    $9.6 B  67          China
# 197  195              Marijke Mars    $9.6 B  58  United States
# 198  195               Pamela Mars    $9.6 B  62  United States
# 199  195              Valerie Mars    $9.6 B  64  United States
#
#                  Source               Industry
# 0                  LVMH       Fashion & Retail
# 1         Tesla, SpaceX             Automotive
# 2                Amazon             Technology
# 3                Oracle             Technology
# 4    Berkshire Hathaway  Finance & Investments
# ..                  ...                    ...
# 195        Solar panels                 Energy
# 196           Chemicals          Manufacturing
# 197     Candy, pet food        Food & Beverage
# 198     Candy, pet food        Food & Beverage
# 199     Candy, pet food        Food & Beverage
#
# [200 rows x 7 columns]

# %% [markdown]
# # Question 8

# %%
driver.get("https://www.youtube.com/watch?v=IEfBBYmxtIo")
time.sleep(10)

# %%
comments=[]
time_comments=[]
upvotes=[]

# %%
for _ in range(100):
    driver.execute_script("window.scrollBy(0,1000)")
    time.sleep(10)
    
    
comment=driver.find_elements(By.XPATH,'//yt-formatted-string[@id="content-text"]')
for i in comment[0:500]:
    comments.append(i.text)
    
time_comment=driver.find_elements(By.XPATH,'//yt-formatted-string[@class="published-time-text style-scope ytd-comment-renderer"]')
for i in time_comment[0:500]:
    time_comments.append(i.text)


upvote=driver.find_elements(By.XPATH,'//span[@id="vote-count-middle"]')
for i in upvote[0:500]:
    upvotes.append(i.text)

# %%
print(len(comments),len(time_comments),len(upvotes))
# Out:
# 500 500 500

# %%
df7=pd.DataFrame({"Comments":comments,"Time":time_comments,"Upvotes":upvotes})
df7
# Out:
#                                               Comments                  Time  \
# 0    First\nAur ek baat naya show tayyar hai. Ticke...           3 weeks ago
# 1                             No one can beat bassii.   3 weeks ago (edited)
# 2    I have never laughed for continuous 37 minutes...            9 days ago
# 3    No vulgar jokes, no hurting anyone. Just pure ...           2 weeks ago
# 4    After 5 months i really smiled thanks to you b...            2 days ago
# ..                                                 ...                   ...
# 495                                Masterpiece officer           2 weeks ago
# 496  "Mujhe chauk de budhiya"...my favourite line f...           12 days ago
# 497  There is much more loud sound of audience clap...            3 days ago
# 498  Bhai sahab  the og content of comedy  want mor...           2 weeks ago
# 499  Officer, salute rakho. Tummy is cramping from ...            3 days ago
#
#     Upvotes
# 0       13K
# 1       18K
# 2       464
# 3       933
# 4        18
# ..      ...
# 495
# 496       1
# 497
# 498
# 499
#
# [500 rows x 3 columns]

# %% [markdown]
# # Question 9

# %%
driver.get("https://www.hostelworld.com")

# %%
role18=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/input')
role18.send_keys('London')
time.sleep(5)

# %%
role19=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[1]/div[2]/div/ul/li[2]')
role19.click()
time.sleep(5)

# %%
role20=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[5]/button')
role20.click()
time.sleep(5)

# %%
Property=[]
P_rating=[]
P_review=[]
P_keyword=[]
P_distance=[]
P_price=[]
S_price=[]
P_facility=[]
P_description=[]
P_url=[]

# %%
p_url=driver.find_elements(By.XPATH,'//a[@class="nuxt-link"]')
for i in p_url[2:33]:
    P_url.append(i.get_attribute('href'))

# %%
len(P_url)
# Out:
# 30

# %%
p_distance=driver.find_elements(By.XPATH,'//span[@class="distance-description"]')
for i in p_distance:
    P_distance.append(i.text)
    
p_price=driver.find_elements(By.XPATH,'//div[@class="property-accommodation-prices"]')
for i in p_price:
    P_price.append(i.text.split('\n')[1])
    
s_price=driver.find_elements(By.XPATH,'//div[@class="property-accommodation-prices"]')
for i in s_price:
    S_price.append(i.text.split('\n')[2])

# %%
for i in P_url:
    driver.get(i)
    
    

    p_rating=driver.find_element(By.XPATH,'//*[@class="reviews-and-ratings"]/div[1]/div[1]/div[1]')
    P_rating.append(p_rating.text)



    p_review=driver.find_element(By.XPATH,'//*[@class="reviews-and-ratings"]/div[1]/div[1]/div[2]/div[2]')
    P_review.append(p_review.text)





    prop=driver.find_element(By.XPATH,'//div[@class="title-2"]')
    Property.append(prop.text)





    p_facility=driver.find_element(By.XPATH,'//*[@class="facilities-container"]/ul[1]/li[1]/ul[1]')
    P_facility.append(p_facility.text)




    p_description=driver.find_element(By.XPATH,'//*[@class="description-container"]/div[1]/div[2]')
    P_description.append(p_description.text)




    p_keyword=driver.find_element(By.XPATH,'//*[@class="reviews-and-ratings"]/div[1]/div[1]/div[2]/div/span')
    P_keyword.append(p_keyword.text)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[183], line 6
#       1 for i in P_url:
#       2     driver.get(i)
# ----> 6     p_rating=driver.find_element(By.XPATH,'//*[@class="reviews-and-ratings"]/div[1]/div[1]/div[1]')
#       7     P_rating.append(p_rating.text)
#      11     p_review=driver.find_element(By.XPATH,'//*[@class="reviews-and-ratings"]/div[1]/div[1]/div[2]/div[2]')
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:740, in WebDriver.find_element(self, by, value)
#     737     by = By.CSS_SELECTOR
#     738     value = f'[name="{value}"]'
# --> 740 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:346, in WebDriver.execute(self, driver_command, params)
#     344 response = self.command_executor.execute(driver_command, params)
#     345 if response:
# --> 346     self.error_handler.check_response(response)
#     347     response["value"] = self._unwrap_value(response.get("value", None))
#     348     return response
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@class="reviews-and-ratings"]/div[1]/div[1]/div[1]"}
#   (Session info: chrome=115.0.5790.111); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x0091A813+48355]
# 	(No symbol) [0x008AC4B1]
# 	(No symbol) [0x007B5358]
# 	(No symbol) [0x007E09A5]
# 	(No symbol) [0x007E0B3B]
# 	(No symbol) [0x0080E232]
# 	(No symbol) [0x007FA784]
# 	(No symbol) [0x0080C922]
# 	(No symbol) [0x007FA536]
# 	(No symbol) [0x007D82DC]
# 	(No symbol) [0x007D93DD]
# 	GetHandleVerifier [0x00B7AABD+2539405]
# 	GetHandleVerifier [0x00BBA78F+2800735]
# 	GetHandleVerifier [0x00BB456C+2775612]
# 	GetHandleVerifier [0x009A51E0+616112]
# 	(No symbol) [0x008B5F8C]
# 	(No symbol) [0x008B2328]
# 	(No symbol) [0x008B240B]
# 	(No symbol) [0x008A4FF7]
# 	BaseThreadInitThunk [0x7790FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77B17A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77B17A6E+238]

# %%
df6=pd.DataFrame({"Hostel Name":Property,"Distance from the city centre":P_distance,"Ratings":P_rating,"Total reviews":P_review,"overall reviews":P_keyword,"privates from price":P_price,"dorms from price":S_price,"facilities":P_facility,"description":P_description})
df6
# Out:
#                                 Hostel Name Distance from the city centre  \
# 0                       YHA London St Pauls      - 1.9km from city centre
# 1                        Strand Continental      - 1.3km from city centre
# 2                         The Backpackshack     - 10.9km from city centre
# 3                         Mornington Camden      - 4.1km from city centre
# 4                         Bell House Hostel      - 4.2km from city centre
# 5      PubLove @ The Steam Engine, Waterloo      - 0.5km from city centre
# 6              International Students House      - 3.3km from city centre
# 7                    London Waterloo Hostel      - 0.7km from city centre
# 8                             Selina Camden      - 5.5km from city centre
# 9                          Generator London        - 3km from city centre
# 10  St Christopher's Inn - Liverpool Street      - 3.2km from city centre
# 11                 St Christopher's Village      - 1.8km from city centre
# 12        Safestay London Elephant & Castle      - 1.7km from city centre
# 13     St Christopher's Inn - London Bridge      - 1.8km from city centre
# 14                           Astor Victoria      - 1.8km from city centre
# 15       PubLove @ The Exmouth Arms, Euston      - 3.4km from city centre
# 16        Onefam Notting Hill by Hostel One      - 5.5km from city centre
# 17                     Urbany Hostel London      - 5.4km from city centre
# 18               Kabannas London St Pancras      - 3.3km from city centre
# 19                       YHA London Central      - 2.9km from city centre
# 20              Smart Russell Square Hostel      - 2.6km from city centre
# 21              Wombat's City Hostel London      - 3.6km from city centre
# 22      PubLove @ The Green Man, Paddington      - 4.3km from city centre
# 23               PubLove @ The Rose & Crown      - 1.6km from city centre
# 24                         Astor Museum Inn      - 2.2km from city centre
# 25                           Phoenix Hostel      - 4.2km from city centre
# 26             No.8 Willesden Hostel London       - 10km from city centre
# 27                       No.8 Seven Sisters        - 9km from city centre
# 28                 Kensal Green Backpackers      - 8.2km from city centre
# 29                  Smart Camden Inn Hostel      - 4.4km from city centre
#
#    Ratings        Total reviews overall reviews privates from price  \
# 0      8.8   2089 Total Reviews        Fabulous             ₹18,304
# 1      6.2    976 Total Reviews            Good              ₹7,920
# 2      8.6    768 Total Reviews        Fabulous              ₹7,920
# 3      6.7     56 Total Reviews            Good          Dorms From
# 4      7.6     80 Total Reviews       Very Good          Dorms From
# 5      8.0    409 Total Reviews        Fabulous          Dorms From
# 6      8.9   1060 Total Reviews        Fabulous             ₹12,390
# 7      5.8   2542 Total Reviews          Rating             ₹10,613
# 8      8.7     54 Total Reviews        Fabulous             ₹17,825
# 9      7.6   7629 Total Reviews       Very Good             ₹11,196
# 10     8.2    511 Total Reviews        Fabulous                -10%
# 11     8.1  12297 Total Reviews        Fabulous                -10%
# 12     7.2   5038 Total Reviews       Very Good          Dorms From
# 13     7.8   3528 Total Reviews       Very Good                -10%
# 14     7.1  14997 Total Reviews       Very Good          Dorms From
# 15     6.8   1084 Total Reviews            Good          Dorms From
# 16     9.6   2167 Total Reviews          Superb             ₹19,030
# 17     9.5    846 Total Reviews          Superb             ₹15,876
# 18     9.2   2871 Total Reviews          Superb          Dorms From
# 19     8.4   4766 Total Reviews        Fabulous             ₹25,697
# 20     7.5  10057 Total Reviews       Very Good          Dorms From
# 21     9.0  15136 Total Reviews          Superb       Privates From
# 22     5.5    450 Total Reviews          Rating             ₹13,306
# 23     7.7    198 Total Reviews       Very Good          Dorms From
# 24     8.2   9296 Total Reviews        Fabulous          Dorms From
# 25     8.0   4313 Total Reviews        Fabulous                 -5%
# 22  The Green Man Bestplace Inn is next door to Ed...
# 23  Food & culture lovers, assemble!\nThe Rose & C...
# 24  Note: 18-40 yrs old only. Astor Museum won 1st...
# 25  The Phoenix Bar & Hostel, housed in a homely E...
# 26  At No.8 we take pride in our Customer Service ...
# 27  For Great Facilities, Comfort & Affordability ...
# 28  Kensal Green Backpackers is a legendary hostel...
# 29  Located in the middle of Camden Town, we’re th...

# %%
print(len(Property),len(P_distance),len(P_rating),len(P_review),len(P_keyword),len(P_price),len(S_price),len(P_facility),len(P_url),len(P_description))
# Out:
# 30 30 30 30 29 30 30 30 30 30

# %%
P_description
# Out:
# ["YHA London Earls Court has been recommended by Hostelworld guests for its 'cheerful, friendly and helpful welcoming staff'. Our visitors tell us this 'immaculately-presented hostel' offers 'bright and airy' common rooms with 'notice boards full of fun ideas for things to do at value prices' as well as a 'great location, reasonable price and plenty of space in the dorms'. One user commented that 'Earls Court itself is the perfect spot, crossing two main metro lines and one easy metro ride from Heathrow'. We like their all-you-can-eat continental breakfast.",
#  "YHA London Earls Court has been recommended by Hostelworld guests for its 'cheerful, friendly and helpful welcoming staff'. Our visitors tell us this 'immaculately-presented hostel' offers 'bright and airy' common rooms with 'notice boards full of fun ideas for things to do at value prices' as well as a 'great location, reasonable price and plenty of space in the dorms'. One user commented that 'Earls Court itself is the perfect spot, crossing two main metro lines and one easy metro ride from Heathrow'. We like their all-you-can-eat continental breakfast.",
#  "If your main interest in London is museums and history, YHA London St Pauls is an ideal place to stay while exploring the city's culture. Our visitors say this hostel is 'fantastic for price and location'-it's near the Tate Modern, St Paul's Cathedral, London Bridge and South Bank. Hostelworld guests have praised the 'dedicated' staff, the on-site restaurant and the notably clean facilities of this hostel, only 200m from St Paul's tube station.",
#  "Pickwick Hall provides accommodation for tourists, students and other people who require cheap, clean and attractive short or long-term lodging. We are situated in central London, in the famous area of Bloomsbury, where writers and artists have lived for centuries. Pickwick Hall is in the perfect location, about a four-minute walk from the British Museum and the University of London and about 10 minutes from the entertainment and shopping districts of the West End, Covent Garden, Soho, and China Town, but in a quiet street of Georgian town houses. \n\nThere is easy and direct access from Heathrow Airport by tube (straight to Holborn Station on the Piccadilly line) and train and coach connections to the other London airports and Eurostar train terminal. Choose either 'en-suite rooms' (with their own private bathroom) or the less expensive 'standard rooms' (with showers and toilets on the same floor shared with a limited number of other guests). \n\nWhichever you choose, the room will be furnished with hotel-quality beds (no bunk beds), clothes storage, a table and chair, and a wash-hand basin. Bed linen and towels provided; continental breakfast and kitchen available to prepare your own meals. There is a sitting room with cable television and high-speed WiFi is available throughout Pickwick Hall. \n\nOur staff is on hand to answer your queries and a high standard is maintained to ensure your stay with us is comfortable. \n\nPickwick Hall is a small hostel where you can expect personal attention and good accommodation at a reasonable price.",
#  "Welcome to one of London's cheapest, friendliest and well-located hostels! Situated in the heart of the West End, opposite Covent Garden, and 10 minutes walk from Trafalgar Square and the London Eye. There are theatres, restaurants and nightlife all on your doorstep!\n\nOffering both mixed dormitories and single, double and family rooms. All rooms are equipped with washbasins, and have shared bathroom facilities. There is also a 1940s bar and restaurant which are great for meeting other travellers. \n\nGuests can enjoy:\nNo curfew\nFree WI-FI in the lounge (no WI-FI in the bedrooms)\n24 hour reception\nLinen included \nTowels included in private rooms (not in dorms). You can bring your own or rent them for Â£2 each towel\nTea/Coffee making facilities (in private rooms)\nSafe luggage storage free of charge\nMultilingual staff: English, Spanish, French, Hindi, Polish\nSorry, no lift!\n\nCheck in time: 2:00 pm\nCheck out: 10:00 am\nCash or credit/debit cards accepted.\n\nCancellation policy:\nGuests can cancel their bookings free of charge uptil 24 hours prior to arrival. Failure to give a 24 hour cancellation notice will result in the total booking being charged.\n\nPlease note that a £5 key deposit in cash will be charged on arrival, and returned to guests when they return their room key on departure. There is no lift and rooms start from the third floor upwards.\n\nIn order to confirm the booking, you need to provide us with the CVC/CVV/Security number on the back of the card used to book on this site. Please send this to our email address. Failure to comply with this can result in your booking being cancelled.\n\nFor guest staying over 31st December the following applies: 2 nights minimum stay. Payment is taken at the time of booking. Bookings are non-refundable.",
#  "YHA London Central is often mentioned by our guests as having 'exceptionally pleasant and helpful' staff who offer 'good service' and a wide knowledge of London. Hostelworld users also frequently praise this hostel's 'modern and clean' rooms, with one review comparing it to a 'well above-average hotel'. We like their 24hr café - perfect if you want to grab some breakfast before catching an early-morning train.",
#  'Female Only Mornington Camden Hostel is a high class spacious town house with a lovely warm atmosphere. Everything is new. \nThe staff are very friendly and helpful. We have a nice lounge with a TV, and a Bar, and restaurant with cheap high quality food. The room has 10 beds, or 5 bunk beds, for females only\n\nMany restaurants, traditional pubs and bars are nearby and breakfast and snacks can be purchased next door in our sister building, the Crescent Cafe, at a discount. The renowned Camden market, Regents Park, London Zoo and Fitzrovia are within walking distance. Kings Cross, Euston and St Pancras (Eurostar) are within easy reach. \n\nAll beds have\nUSB charging points on the electrical sockets. \nFree Linen and Towels. \nFree Lockers\nFull Privacy\nPersonal Lamp\nFull use of a private garden\nFree Coffee and Tea\nFree Washing Machine use\nFree bag storage\n24 hour access if arranged with us beforehand\n\n\nMornington Camden policies & conditions;\n\nCancellation policy: 24h before arrival 6 PM\n\nCheck in from 14:00 to 23:00.\nCheck out before 11:00.\nIf you wish to check in earlier or store luggage contact us prior on reservations@thehurdwick.com to arrange this and time of check in \n\nPayment upon arrival by cash, credit cards, debit cards. This property may pre-authorise your card before arrival.\n\nTaxes included.\nBreakfast not included.\n\nGeneral;\nNo curfew.\nMinimum age = You must be 16 or over to stay in a dormitory / group room.\nWe operate a no-smoking policy throughout the building.\nThe maximum period of stay is of 30 days.',
#  "Boasting a bar and a shared lounge, Bell House Hostel is set in London.\n\nAt the hostel, the rooms are equipped with a shared bathroom with a shower.\n\nGuests at Bell House Hostel can enjoy a continental breakfast.\n\n1 km from Madame Tussauds and 1.1 km from Lord's Cricket Ground. \n\nThe property is around 1.1 km from Paddington Station, 2 km from Regents Park, and 2.3 km from Oxford Street. \n\nOxford Circus is 2.8 km from the hostel and Euston Station is 3.3 km away.\n
#  'The Phoenix Bar & Hostel, housed in a homely English-style pub located between Hyde park and Regents park, the Phoenix is perfect located and walking distance to all main attractions, train stations, tubes being only 100+ yards away. \n\nWe are an award winning backpackers hostel. Operating for 13 years we take all of our guests safety and security seriously but we also know how to party! Enjoying a mixed entertainments program down at the bar, Comedy Night, Karaoke, Quiz nights... Lounge area to relax watch TV or a movie. \n\nCome and join us on your next trip to London! \n\nAt the Phoenix Hostel we understand the health and safety concerns of travellers and can assure all guests we are doing everything possible to make your experience safe and enjoyable. A must: Government approved ID on check in for all members of your group!\n\nThe health and safety of our guests and staff are our number one priority, therefore we have updated our current standards and conditions to reflect this. \n\n*Please note we are operating on LIMITED reception working hours*\n\nAt the Phoenix Hostel we understand the health and safety concerns of travellers and can assure all guests we are doing everything possible to make your experience safe and enjoyable. A must: Government approved ID on check in for all members of your group!\n\nThe health and safety of our guests and staff are our number one priority, therefore we have updated our current standards and conditions to reflect this. \n\n£10 key deposit required upon check-in. cash. Refunded on check out.\n\nHostel reception open hours:\n***We have 24 Hours Reception*** \n\nGuests can check-in from 2pm on day of arrival (If arriving earlier, guests may leave their luggage in our holding room until check-in)\n\nCheck-out of rooms by 10AM\n\nForms of ID accepted:\nUK/ROI Driving Licence\nEU/EEA Identity Card \nInternational Passport\nIf you do not have these forms of ID, and wish to stay here, please contact us. \n\nGuests can cancel their reservation up to 2 days before Check in date. After this date the full amount will be charged. \nPayment is taken in full upon arrival, and is non-refundable should the guest wish to alter their booking after check in.',
#  'At No.8 we take pride in our Customer Service and ensure that all of our Guests get everything they want from their time in London. We cater for the Young & Young at Heart Backpacker 18-48 only, Photo IDs will be required on Check In. We have Live Entertainment on Weekends within our Traditional English Pub, along with the usual range of pub entertainment and banter!\n\n- Free High-Speed WiFi\n- Full Facility Kitchen, Dining Space & Outdoor Deck\n- Secure Storage Facilities & 24 Hr Key Card Access\n- Large Lounge - Pool Table, Chess Table, Couches, Satellite TV & Darts Board etc. \n- Traditional English Pub & Beer Garden\n- Young & Young at Heart Backpackers 18-48 only. ID on Check-In Required.\n- Payment by Cash only on Check in (Cards not accepted)\n- £20 Key Deposit (Fully Refunded On Check-Out)\n- No refunds are made following Check-In\n- Reception is open from 9:30am-11:00pm.\n- Groups of 8 or less only. Facilities cannot cater for larger groups unfortunately.\n\n\nCheck in: 12pm - 11pm\nPLEASE NOTE that Check In will NOT be possible outside these hours. If you are running late or will be arriving slightly outside our check in hours, please contact us to see if there is a possibility of us accommodating your arrival outside of check in hours.\n\nWhether it is your first time in London or you are a seasoned traveller, No.8 has everything you need (and a few extras) to ensure that your stay in London is definitely Enjoyable & Comfortable!',
#  "For Great Facilities, Comfort & Affordability you can't go past No.8 Seven Sisters! We provide Excellent Service and ensure that all of our Guests get Everything they want from their time in London. We cater exclusively for the Young & Young at Heart Backpacker 18-48, Photo IDs are required on Check In, as we have Entertainment on Weekends and operate a Very 'Bustling' and Social Hostel.\n\n- Free WiFi\n- Full Facility Kitchen\n- Secure Storage Facilities & 24Hr Key Card Access\n- Pool Table & Darts Board\n- Satellite TV\n- Traditional English Pub & Beer Garden\n- Entertainment on Weekends!\n- Young & Young at Heart Backpackers 18-48 Years Old Only.\n- Payment by Cash only on Check in. (Credit cards not accepted)\n- £20 Key Deposit (Fully Refunded On Check-Out)\